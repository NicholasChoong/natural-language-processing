# %% [markdown]
# <a href="https://colab.research.google.com/github/NicholasChoong/natural-language-processing/blob/main/lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab08

# %% [markdown]
# # Transformer with PyTorch

# %% [markdown]
# ## Sequence-to-Sequence Modeling with nn.Transformer and TorchText
# ================================================================================
#
# This sample code is from the [Official Doc of PyTorch](https://pytorch.org/tutorials/beginner/transformer_tutorial.html) for seq2seq modeling using Transformer.

# %%
# The torchtext package is part of the PyTorch project, which consists of data processing utilities and popular datasets for natural language.
# !pip3 install torchtext==0.4.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchtext==0.4.0
#   Downloading torchtext-0.4.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (2.27.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (2.0.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (3.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchtext==0.4.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchtext==0.4.0) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchtext==0.4.0) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchtext==0.4.0) (1.3.0)
# Installing collected packages: torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.1
#     Uninstalling torchtext-0.15.1:
#       Successfully uninstalled torchtext-0.15.1
# Successfully installed torchtext-0.4.0

# %% [markdown]
# In this sample code, we will learn about how to train a sequence-to-sequence model
# that uses the
# [nn.Transformer](https://pytorch.org/docs/master/nn.html?highlight=nn%20transformer#torch.nn.Transformer) module.
#
# PyTorch 1.2 release includes a standard transformer module based on the
# paper [Attention is All You
# Need](https://arxiv.org/pdf/1706.03762.pdf) . The transformer model
# has been proved to be superior in quality for many sequence-to-sequence
# problems while being more parallelizable. The ``nn.Transformer`` module
# relies entirely on an attention mechanism (another module recently
# implemented as [nn.MultiheadAttention](https://pytorch.org/docs/master/nn.html?highlight=multiheadattention#torch.nn.MultiheadAttention)) to draw global dependencies
# between input and output. The ``nn.Transformer`` module is now highly
# modularized such that a single component (like `nn.TransformerEncoder`
# in this tutorial) can be easily adapted/composed.
#
#
# Recall: We just practised how to implement the attention mechanism in Lab 7 🤤
#
# ![](https://github.com/pytorch/tutorials/blob/gh-pages/_static/img/transformer_architecture.jpg?raw=1)

# %% [markdown]
# ### Define the model
# ----------------

# %% [markdown]
# In this sample code, we train ``nn.TransformerEncoder`` model on a
# language modeling task. The language modeling task is to assign a
# probability for the likelihood of a given word (or a sequence of words)
# to follow a sequence of words.
#
# A sequence of tokens are passed to the embedding
# layer first, followed by a positional encoding layer to account for the order
# of the word (see the next paragraph for more details). The
# ``nn.TransformerEncoder`` consists of multiple layers of
# [nn.TransformerEncoderLayer](https://pytorch.org/docs/master/nn.html?highlight=transformerencoderlayer#torch.nn.TransformerEncoderLayer) . Along with the input sequence, a square
# attention mask is required because the self-attention layers in
# ``nn.TransformerEncoder`` are only allowed to attend the earlier positions in
# the sequence. For the language modeling task, any tokens on the future
# positions should be masked. To have the actual words, the output
# of ``nn.TransformerEncoder`` model is sent to the final Linear
# layer, which is followed by a log-Softmax function.

# %% [markdown]
# #### Transformer Model

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F

class TransformerModel(nn.Module):

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__()
        from torch.nn import TransformerEncoder, TransformerEncoderLayer
        self.model_type = 'Transformer'
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def _generate_square_subsequent_mask(self, sz):
        #triu returns the upper triangular part of a matrix (2-D tensor) or batch of matrices (see section below)
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, src):
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask

        src = self.encoder(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, self.src_mask)
        output = self.decoder(output)
        return output

# %% [markdown]
# ##### Masking
# By passing the mask into the transformer_encoder forward() function, the attention will only be calculated on the earlier positions in the sequence.

# %%
#triu returns the upper triangular part of a matrix (2-D tensor) or batch of matrices (see section below)
torch.triu(torch.ones(3, 3))
# Out:
# tensor([[1., 1., 1.],
#         [0., 1., 1.],
#         [0., 0., 1.]])

# %%
# Masking
def masking():
  sz = 4
  mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
  mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
  
  return mask

masking()
# Out:
# tensor([[0., -inf, -inf, -inf],
#         [0., 0., -inf, -inf],
#         [0., 0., 0., -inf],
#         [0., 0., 0., 0.]])

# %% [markdown]
# #### Positional Encoding

# %% [markdown]
# Transformer architecture takes base architecture of Seq2Seq model (Encoder - Decoder). However, the transformer does not use recurrent model so this means we need a module that captures sequence information of the input/output.
#
# ``PositionalEncoding`` module injects some information about the
# relative or absolute position of the tokens in the sequence. The
# positional encodings have the same dimension as the embeddings so that
# the two can be summed. Here, we use ``sine`` and ``cosine`` functions of
# different frequencies.

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term) #0::2 means starting with index 0, step = 2
        pe[:, 1::2] = torch.cos(position * div_term) 
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# %% [markdown]
# ### Load and batch data
# -------------------

# %% [markdown]
# The training process uses Wikitext-2 dataset from ``torchtext``. The
# vocab object is built based on the train dataset and is used to numericalize
# tokens into tensors. Starting from sequential data, the ``batchify()``
# function arranges the dataset into columns, trimming off any tokens remaining
# after the data has been divided into batches of size ``batch_size``.
# For instance, with the alphabet as the sequence (total length of 26)
# and a batch size of 4, we would divide the alphabet into 4 sequences of
# length 6:
#
# \begin{align}\begin{bmatrix}
#   \text{A} & \text{B} & \text{C} & \ldots & \text{X} & \text{Y} & \text{Z}
#   \end{bmatrix}
#   \Rightarrow
#   \begin{bmatrix}
#   \begin{bmatrix}\text{A} \\ \text{B} \\ \text{C} \\ \text{D} \\ \text{E} \\ \text{F}\end{bmatrix} &
#   \begin{bmatrix}\text{G} \\ \text{H} \\ \text{I} \\ \text{J} \\ \text{K} \\ \text{L}\end{bmatrix} &
#   \begin{bmatrix}\text{M} \\ \text{N} \\ \text{O} \\ \text{P} \\ \text{Q} \\ \text{R}\end{bmatrix} &
#   \begin{bmatrix}\text{S} \\ \text{T} \\ \text{U} \\ \text{V} \\ \text{W} \\ \text{X}\end{bmatrix}
#   \end{bmatrix}\end{align}
#
# These columns are treated as independent by the model, which means that
# the dependence of ``G`` and ``F`` can not be learned, but allows more
# efficient batch processing.

# %%
import torchtext
from torchtext.data.utils import get_tokenizer
TEXT = torchtext.data.Field(tokenize=get_tokenizer("basic_english"),
                            init_token='<sos>',
                            eos_token='<eos>',
                            lower=True)
train_txt, val_txt, test_txt = torchtext.datasets.WikiText2.splits(TEXT)
TEXT.build_vocab(train_txt)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def batchify(data, bsz):
    data = TEXT.numericalize([data.examples[0].text])
    # Divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

batch_size = 20
eval_batch_size = 10
train_data = batchify(train_txt, batch_size)
val_data = batchify(val_txt, eval_batch_size)
test_data = batchify(test_txt, eval_batch_size)
# Out:
# downloading wikitext-2-v1.zip
# wikitext-2-v1.zip: 100%|██████████| 4.48M/4.48M [00:01<00:00, 2.89MB/s]
# extracting

# %% [markdown]
# Functions to generate input and target sequence

# %% [markdown]
# ``get_batch()`` function generates the input and target sequence for
# the transformer model. It subdivides the source data into chunks of
# length ``bptt``. For the language modeling task, the model needs the
# following words as ``Target``. For example, with a ``bptt`` value of 2,
# we’d get the following two Variables for ``i`` = 0:
#
# ![](https://github.com/pytorch/tutorials/blob/gh-pages/_static/img/transformer_input_target.png?raw=1)
#
#
# It should be noted that the chunks are along dimension 0, consistent
# with the ``S`` dimension in the Transformer model. The batch dimension
# ``N`` is along dimension 1.

# %%
bptt = 35
def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target

# %% [markdown]
# ### Initiate an instance
# --------------------

# %% [markdown]
# The model is set up with the hyperparameter below. The vocab size is
# equal to the length of the vocab object.

# %%
ntokens = len(TEXT.vocab.stoi) # the size of vocabulary
emsize = 200 # embedding dimension
nhid = 200 # the dimension of the feedforward network model in nn.TransformerEncoder
nlayers = 6 # the number of nn.TransformerEncoderLayer in nn.TransformerEncoder
nhead = 2 # the number of heads in the multiheadattention models
dropout = 0.2 # the dropout value
model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)

# %% [markdown]
# ### Run the model
# -------------

# %% [markdown]
# `CrossEntropyLoss `
# is applied to track the loss and
# `SGD `
# implements stochastic gradient descent method as the optimizer. The initial
# learning rate is set to 5.0. `StepLR ` is
# applied to adjust the learning rate through epochs. During the
# training, we use
# `nn.utils.clip_grad_norm_ `
# function to scale all the gradient together to prevent exploding.

# %%
criterion = nn.CrossEntropyLoss()
lr = 5.0 # learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

import time
def train():

    model.train() # Turn on the train mode
    total_loss = 0.
    start_time = time.time()
    ntokens = len(TEXT.vocab.stoi)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, targets = get_batch(train_data, i)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        log_interval = 200
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.2f} | ms/batch {:5.2f} | '
                  'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // bptt, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()


def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    ntokens = len(TEXT.vocab.stoi)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, bptt):
            data, targets = get_batch(data_source, i)
            output = eval_model(data)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
    return total_loss / (len(data_source) - 1)

# %% [markdown]
# Loop over epochs. Save the model if the validation loss is the best
# we've seen so far. Adjust the learning rate after each epoch.

# %%
best_val_loss = float("inf")
epochs = 3 # The number of epochs
best_model = None

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train()
    val_loss = evaluate(model, val_data)
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
          'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model

    scheduler.step()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:389: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 47.64 | loss  8.39 | ppl  4386.97
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 26.14 | loss  7.47 | ppl  1759.99
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 22.24 | loss  7.19 | ppl  1325.73
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 19.40 | loss  7.08 | ppl  1193.70
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 18.76 | loss  7.05 | ppl  1150.43
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 18.70 | loss  7.02 | ppl  1115.19
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 20.05 | loss  6.97 | ppl  1063.75
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 18.90 | loss  6.97 | ppl  1063.94
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 19.06 | loss  6.95 | ppl  1039.24
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 19.91 | loss  6.96 | ppl  1050.96
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 18.87 | loss  6.93 | ppl  1019.96
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 18.85 | loss  6.93 | ppl  1021.57
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 20.07 | loss  6.92 | ppl  1015.51
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 18.99 | loss  6.90 | ppl   988.95
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 68.70s | valid loss  6.80 | valid ppl   898.32
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 4.51 | ms/batch 19.73 | loss  6.93 | ppl  1022.84
# | epoch   2 |   400/ 2981 batches | lr 4.51 | ms/batch 19.17 | loss  6.91 | ppl  1000.58
# | epoch   2 |   600/ 2981 batches | lr 4.51 | ms/batch 19.31 | loss  6.88 | ppl   973.00
# | epoch   2 |   800/ 2981 batches | lr 4.51 | ms/batch 24.02 | loss  6.90 | ppl   996.11
# | epoch   2 |  1000/ 2981 batches | lr 4.51 | ms/batch 19.42 | loss  6.90 | ppl   988.05
# | epoch   2 |  1200/ 2981 batches | lr 4.51 | ms/batch 19.66 | loss  6.91 | ppl  1003.03
# | epoch   2 |  1400/ 2981 batches | lr 4.51 | ms/batch 20.23 | loss  6.89 | ppl   984.09
# | epoch   2 |  1600/ 2981 batches | lr 4.51 | ms/batch 19.30 | loss  6.91 | ppl  1003.84
# | epoch   2 |  1800/ 2981 batches | lr 4.51 | ms/batch 19.43 | loss  6.89 | ppl   980.98
# | epoch   2 |  2000/ 2981 batches | lr 4.51 | ms/batch 20.49 | loss  6.91 | ppl  1001.68
# | epoch   2 |  2200/ 2981 batches | lr 4.51 | ms/batch 19.56 | loss  6.89 | ppl   979.41
# | epoch   2 |  2400/ 2981 batches | lr 4.51 | ms/batch 19.64 | loss  6.89 | ppl   978.69
# | epoch   2 |  2600/ 2981 batches | lr 4.51 | ms/batch 20.66 | loss  6.88 | ppl   976.95
# | epoch   2 |  2800/ 2981 batches | lr 4.51 | ms/batch 19.69 | loss  6.86 | ppl   953.94
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 63.67s | valid loss  6.75 | valid ppl   850.04
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 4.29 | ms/batch 19.33 | loss  6.90 | ppl   993.23
# | epoch   3 |   400/ 2981 batches | lr 4.29 | ms/batch 19.27 | loss  6.88 | ppl   976.93
# | epoch   3 |   600/ 2981 batches | lr 4.29 | ms/batch 20.16 | loss  6.85 | ppl   947.78
# | epoch   3 |   800/ 2981 batches | lr 4.29 | ms/batch 19.30 | loss  6.89 | ppl   979.27
# | epoch   3 |  1000/ 2981 batches | lr 4.29 | ms/batch 19.34 | loss  6.87 | ppl   965.14
# | epoch   3 |  1200/ 2981 batches | lr 4.29 | ms/batch 20.09 | loss  6.89 | ppl   984.89
# | epoch   3 |  1400/ 2981 batches | lr 4.29 | ms/batch 19.59 | loss  6.87 | ppl   963.63
# | epoch   3 |  1600/ 2981 batches | lr 4.29 | ms/batch 19.21 | loss  6.88 | ppl   977.38
# | epoch   3 |  1800/ 2981 batches | lr 4.29 | ms/batch 19.63 | loss  6.87 | ppl   962.99
# | epoch   3 |  2000/ 2981 batches | lr 4.29 | ms/batch 19.84 | loss  6.89 | ppl   981.81
# | epoch   3 |  2200/ 2981 batches | lr 4.29 | ms/batch 19.31 | loss  6.86 | ppl   953.92
# | epoch   3 |  2400/ 2981 batches | lr 4.29 | ms/batch 19.58 | loss  6.86 | ppl   950.63
# | epoch   3 |  2600/ 2981 batches | lr 4.29 | ms/batch 20.12 | loss  6.86 | ppl   949.45
# | epoch   3 |  2800/ 2981 batches | lr 4.29 | ms/batch 19.35 | loss  6.84 | ppl   930.50
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 62.39s | valid loss  6.76 | valid ppl   865.76
# -----------------------------------------------------------------------------------------

# %% [markdown]
# ### Evaluate the model with the test dataset
# -------------------------------------
#
# Apply the best model to check the result with the test dataset.

# %%
test_loss = evaluate(best_model, test_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)
# Out:
# =========================================================================================
# | End of training | test loss  6.71 | test ppl   820.50
# =========================================================================================

# %% [markdown]
# # Lab 8 Exercise
# Please complete the following **question E1** for Lab 8 and check with your Tutor (Lab Facilitator) in the lab.
#
# **Submission Due**: Your Lab 9 (in Week 10)
#
# **Submission Method**: Show your final code to your tutor during the Lab.

# %% [markdown]
# ## E1. Test with Transformer
# Try ***either*** different number of `heads` in Multi-head Attention, ***or*** different number of `encoders`, and record the test performance (Try `at least 3 variants`). Then visualise a table/graph with the peformance to show ***either*** the test performance (or validation losses/ppls) VS. number of heads, ***or*** the test performance (or validation losses/ppls) VS. number of encoders (you can keep epochs = 3 for all experiments).

# %% [markdown]
# Below are two examples for graph plotting and table printing as demonstration. The graph 1 plots the bar chart where the x-axis is the number of attention heads and y-axis indicates the test ppl value. The graph 2 draws multiple line graphs in one figure, in which each line shows the validation loss over each epoch (x-axis is the epoch number, y-axis is the validation loss value). Similarly, the two tables prints the same information but in the table format.

# %% [markdown]
# ## Graph 1 / Table 1 demonstration

# %%
import matplotlib.pyplot as plt

plt.title("Test performance - Number of heads") # Set graph/figure title
plt.ylabel("Test ppl") # Set y-axis title
plt.xlabel("Number of heads") # Set x-axis title

heads = [1,2,4,8] # assume we try head number of 1, 2, 4, and 8 (i.e., 4 variants)
ppls = [400,300,200,100] # assume we get the corresponding test ppl using each variant head number - you need to get them from your own experiments
plt.bar(heads,ppls) # plot the bar chart

plt.show() # show the bar chart

# More details of .bar() plotting can be found from: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

# %%
from tabulate import tabulate
heads = [1,2,4,8] # assume we try head number of 1, 2, 4, and 8 (i.e., 4 variants)
ppls = [400,300,200,100] # assume we get the corresponding test ppl using each variant head number - you need to get them from your own experiments
table = [['']+['head '+str(i) for i in heads], ['Test ppl']+ppls]
print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒══════════╤══════════╤══════════╤══════════╤══════════╕
# │          │   head 1 │   head 2 │   head 4 │   head 8 │
# ╞══════════╪══════════╪══════════╪══════════╪══════════╡
# │ Test ppl │      400 │      300 │      200 │      100 │
# ╘══════════╧══════════╧══════════╧══════════╧══════════╛

# %% [markdown]
# ## Graph 2 / Table 2 demonstration

# %%
import matplotlib.pyplot as plt
import random

plt.title("Validation performance - Number of encoders") # Set graph/figure title
plt.ylabel("Validation performance") # Set y-axis title
plt.xlabel("Number of epochs") # Set x-axis title

encoders = [2,4,6,8] # assume we tried 4 variants of encoder layers

for encoder in encoders: # for each encoder variant, we will draw one line graph, showing the validation loss of each epoch
  epochs = [1,2,3] # for each variant, we apply 3 epochs. Thus, we will have epoch 1, 2, 3 (or 0, 1, 2 if you starts with 0)
  val_losses = [random.randint(1, 3), random.randint(1, 3), random.randint(1, 3)] # for each epoch, we recorded the validation loss. Note that here we apply random numbers only for demonstration. However, you need to record your real validation loss if needed.
  plt.plot(epochs,val_losses, label="{0} encoders".format(encoder)) # label each line graph with the encoder number (see the actual plotting in the graph below)

plt.legend(); # this turns on the legends, which shows the label for each line graph. You can comment it out and rerun the code to see the difference
plt.show() # show the final figure

# More details of .plot() plotting can be found from: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
from tabulate import tabulate

table=[]
epochs = [1,2,3] # for each variant, we apply 3 epochs. Thus, we will have epoch 1, 2, 3 (or 0, 1, 2 if you starts with 0)

table.append(['']+['epoch '+str(i) for i in encoders]) # append encoder numbers as header

for encoder in encoders: # for each encoder variant, we will have validation loss for each epoch
  
  val_losses = [random.randint(1, 3), random.randint(1, 3), random.randint(1, 3)] # for each epoch, we recorded the validation loss. Note that here we apply random numbers only for demonstration. However, you need to record your real validation loss if needed.
  table.append(['encoder '+str(encoder)]+val_losses) # append each row data to the table

print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒═══════════╤═══════════╤═══════════╤═══════════╕
# │           │   epoch 2 │   epoch 4 │   epoch 6 │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ encoder 2 │         1 │         1 │         1 │
# ├───────────┼───────────┼───────────┼───────────┤
# │ encoder 4 │         3 │         3 │         2 │
# ├───────────┼───────────┼───────────┼───────────┤
# │ encoder 6 │         2 │         3 │         2 │
# ├───────────┼───────────┼───────────┼───────────┤
# │ encoder 8 │         2 │         3 │         1 │
# ╘═══════════╧═══════════╧═══════════╧═══════════╛

# %% [markdown]
# ## Your solution

# %% [markdown]
# Hint: You can easily change the head/encoder number and train the model using the sample code above. For each training, all you need to do is to record the values you need for visualization, e.g., the x and y values if you are using graphs, or the header and row data if you are using tables. Then you can use the graph or table demonstration code to visualize it.

# %%
n_encoders_list = [4, 6, 8]
epoch_test_losses = []

import time
def train(model):

    criterion = nn.CrossEntropyLoss()
    lr = 5.0 # learning rate
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)
  
    model.train() # Turn on the train mode
    total_loss = 0.
    start_time = time.time()
    ntokens = len(TEXT.vocab.stoi)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, targets = get_batch(train_data, i)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        log_interval = 200
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.2f} | ms/batch {:5.2f} | '
                  'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // bptt, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()


def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    ntokens = len(TEXT.vocab.stoi)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, bptt):
            data, targets = get_batch(data_source, i)
            output = eval_model(data)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
    return total_loss / (len(data_source) - 1)

for n_encoders in n_encoders_list:  
  ntokens = len(TEXT.vocab.stoi) # the size of vocabulary
  emsize = 200 # embedding dimension
  nhid = 200 # the dimension of the feedforward network model in nn.TransformerEncoder
  nlayers = n_encoders # the number of nn.TransformerEncoderLayer in nn.TransformerEncoder
  nhead = 2 # the number of heads in the multiheadattention models
  dropout = 0.2 # the dropout value
  model1 = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)

  best_val_loss = float("inf")
  epochs = 6 # The number of epochs
  best_model = None

  test_losses = []
  for epoch in range(1, epochs + 1):
      epoch_start_time = time.time()
      train(model1)
      val_loss = evaluate(model1, val_data)
      print('-' * 89)
      print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
            'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                      val_loss, math.exp(val_loss)))
      print('-' * 89)
      test_losses.append(val_loss)


      if val_loss < best_val_loss:
          best_val_loss = val_loss
          best_model = model1

      scheduler.step()
  epoch_test_losses.append(test_losses)

  test_loss = evaluate(best_model, test_data)
  print('=' * 89)
  print(f"| End of training for {n_encoders} encoders | test loss {test_loss:5.2f} | test ppl {math.exp(test_loss):8.2f}")
  print('=' * 89)
# Out:
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 16.57 | loss  8.39 | ppl  4393.63
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 17.43 | loss  7.47 | ppl  1753.03
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 16.61 | loss  7.19 | ppl  1324.63
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 16.54 | loss  7.08 | ppl  1186.12
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 16.71 | loss  6.71 | ppl   824.57
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 17.28 | loss  6.49 | ppl   661.00
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 16.46 | loss  6.31 | ppl   551.62
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 16.44 | loss  6.24 | ppl   513.67
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 16.96 | loss  6.13 | ppl   458.90
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 16.77 | loss  6.10 | ppl   447.29
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 16.43 | loss  5.98 | ppl   394.29
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 16.58 | loss  6.00 | ppl   402.92
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 17.27 | loss  6.00 | ppl   402.48
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 16.46 | loss  5.89 | ppl   362.41
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 52.58s | valid loss  5.77 | valid ppl   321.56
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 5.00 | ms/batch 17.40 | loss  5.91 | ppl   369.67
# | epoch   2 |   400/ 2981 batches | lr 5.00 | ms/batch 16.49 | loss  5.91 | ppl   368.87
# | epoch   2 |   600/ 2981 batches | lr 5.00 | ms/batch 16.38 | loss  5.78 | ppl   324.57
# | epoch   2 |   800/ 2981 batches | lr 5.00 | ms/batch 16.56 | loss  5.83 | ppl   340.25
# | epoch   2 |  1000/ 2981 batches | lr 5.00 | ms/batch 17.14 | loss  5.75 | ppl   313.06
# | epoch   2 |  1200/ 2981 batches | lr 5.00 | ms/batch 16.45 | loss  5.75 | ppl   315.45
# | epoch   2 |  1400/ 2981 batches | lr 5.00 | ms/batch 16.48 | loss  5.73 | ppl   308.14
# | epoch   2 |  1600/ 2981 batches | lr 5.00 | ms/batch 17.07 | loss  5.75 | ppl   315.27
# | epoch   2 |  1800/ 2981 batches | lr 5.00 | ms/batch 16.86 | loss  5.69 | ppl   294.72
# | epoch   2 |  2000/ 2981 batches | lr 5.00 | ms/batch 16.43 | loss  5.70 | ppl   299.95
# | epoch   2 |  2200/ 2981 batches | lr 5.00 | ms/batch 16.45 | loss  5.59 | ppl   268.69
# | epoch   2 |  2400/ 2981 batches | lr 5.00 | ms/batch 17.37 | loss  5.65 | ppl   284.74
# | epoch   2 |  2600/ 2981 batches | lr 5.00 | ms/batch 16.42 | loss  5.68 | ppl   292.29
# | epoch   2 |  2800/ 2981 batches | lr 5.00 | ms/batch 16.48 | loss  5.59 | ppl   268.32
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 53.05s | valid loss  5.62 | valid ppl   276.04
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 5.00 | ms/batch 16.62 | loss  5.64 | ppl   280.92
# | epoch   3 |   400/ 2981 batches | lr 5.00 | ms/batch 16.42 | loss  5.66 | ppl   287.27
# | epoch   3 |   600/ 2981 batches | lr 5.00 | ms/batch 16.63 | loss  5.51 | ppl   247.01
# | epoch   3 |   800/ 2981 batches | lr 5.00 | ms/batch 17.03 | loss  5.58 | ppl   265.06
# | epoch   3 |  1000/ 2981 batches | lr 5.00 | ms/batch 16.49 | loss  5.52 | ppl   249.30
# | epoch   3 |  1200/ 2981 batches | lr 5.00 | ms/batch 16.46 | loss  5.54 | ppl   255.79
# | epoch   3 |  1400/ 2981 batches | lr 5.00 | ms/batch 17.07 | loss  5.55 | ppl   257.11
# | epoch   3 |  1600/ 2981 batches | lr 5.00 | ms/batch 16.73 | loss  5.58 | ppl   264.96
# | epoch   3 |  1800/ 2981 batches | lr 5.00 | ms/batch 16.48 | loss  5.51 | ppl   247.72
# | epoch   3 |  2000/ 2981 batches | lr 5.00 | ms/batch 16.50 | loss  5.54 | ppl   254.57
# | epoch   3 |  2200/ 2981 batches | lr 5.00 | ms/batch 17.33 | loss  5.42 | ppl   226.61
# | epoch   3 |  2400/ 2981 batches | lr 5.00 | ms/batch 16.48 | loss  5.49 | ppl   243.17
# | epoch   3 |  2600/ 2981 batches | lr 5.00 | ms/batch 16.38 | loss  5.50 | ppl   244.80
# | epoch   3 |  2800/ 2981 batches | lr 5.00 | ms/batch 16.61 | loss  5.44 | ppl   230.32
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 52.54s | valid loss  5.52 | valid ppl   249.40
# -----------------------------------------------------------------------------------------
# | epoch   4 |   200/ 2981 batches | lr 5.00 | ms/batch 16.55 | loss  5.49 | ppl   242.70
# | epoch   4 |   400/ 2981 batches | lr 5.00 | ms/batch 16.78 | loss  5.52 | ppl   250.06
# | epoch   4 |   600/ 2981 batches | lr 5.00 | ms/batch 17.22 | loss  5.36 | ppl   211.70
# | epoch   4 |   800/ 2981 batches | lr 5.00 | ms/batch 16.45 | loss  5.44 | ppl   229.73
# | epoch   4 |  1000/ 2981 batches | lr 5.00 | ms/batch 16.42 | loss  5.40 | ppl   220.59
# | epoch   4 |  1200/ 2981 batches | lr 5.00 | ms/batch 17.20 | loss  5.42 | ppl   225.58
# | epoch   4 |  1400/ 2981 batches | lr 5.00 | ms/batch 16.64 | loss  5.43 | ppl   229.00
# | epoch   4 |  1600/ 2981 batches | lr 5.00 | ms/batch 16.44 | loss  5.46 | ppl   236.08
# | epoch   4 |  1800/ 2981 batches | lr 5.00 | ms/batch 16.52 | loss  5.40 | ppl   221.38
# | epoch   4 |  2000/ 2981 batches | lr 5.00 | ms/batch 17.42 | loss  5.43 | ppl   228.21
# | epoch   4 |  2200/ 2981 batches | lr 5.00 | ms/batch 16.49 | loss  5.31 | ppl   201.64
# | epoch   4 |  2400/ 2981 batches | lr 5.00 | ms/batch 16.55 | loss  5.39 | ppl   220.12
# | epoch   4 |  2600/ 2981 batches | lr 5.00 | ms/batch 16.71 | loss  5.42 | ppl   224.84
# | epoch   4 |  2800/ 2981 batches | lr 5.00 | ms/batch 17.19 | loss  5.33 | ppl   206.68
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 52.62s | valid loss  5.47 | valid ppl   236.61
# -----------------------------------------------------------------------------------------
# | epoch   5 |   200/ 2981 batches | lr 5.00 | ms/batch 16.87 | loss  5.42 | ppl   224.85
# | epoch   5 |   400/ 2981 batches | lr 5.00 | ms/batch 17.01 | loss  5.44 | ppl   230.37
# | epoch   5 |   600/ 2981 batches | lr 5.00 | ms/batch 16.45 | loss  5.26 | ppl   192.72
# | epoch   5 |   800/ 2981 batches | lr 5.00 | ms/batch 16.47 | loss  5.33 | ppl   206.90
# | epoch   5 |  1000/ 2981 batches | lr 5.00 | ms/batch 17.14 | loss  5.31 | ppl   201.54
# | epoch   5 |  1200/ 2981 batches | lr 5.00 | ms/batch 16.71 | loss  5.34 | ppl   209.04
# | epoch   5 |  1400/ 2981 batches | lr 5.00 | ms/batch 16.42 | loss  5.35 | ppl   210.29
# | epoch   5 |  1600/ 2981 batches | lr 5.00 | ms/batch 16.43 | loss  5.38 | ppl   216.94
# | epoch   5 |  1800/ 2981 batches | lr 5.00 | ms/batch 17.40 | loss  5.32 | ppl   204.65
# | epoch   5 |  2000/ 2981 batches | lr 5.00 | ms/batch 16.51 | loss  5.37 | ppl   214.71
# | epoch   5 |  2200/ 2981 batches | lr 5.00 | ms/batch 16.42 | loss  5.23 | ppl   186.33
# | epoch   5 |  2400/ 2981 batches | lr 5.00 | ms/batch 16.68 | loss  5.31 | ppl   202.90
# | epoch   5 |  2600/ 2981 batches | lr 5.00 | ms/batch 17.11 | loss  5.33 | ppl   207.44
# | epoch   5 |  2800/ 2981 batches | lr 5.00 | ms/batch 16.54 | loss  5.24 | ppl   189.20
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 52.81s | valid loss  5.43 | valid ppl   227.32
# -----------------------------------------------------------------------------------------
# | epoch   6 |   200/ 2981 batches | lr 5.00 | ms/batch 17.16 | loss  5.32 | ppl   205.40
# | epoch   6 |   400/ 2981 batches | lr 5.00 | ms/batch 16.47 | loss  5.35 | ppl   211.00
# | epoch   6 |   600/ 2981 batches | lr 5.00 | ms/batch 16.49 | loss  5.17 | ppl   176.64
# | epoch   6 |   800/ 2981 batches | lr 5.00 | ms/batch 17.23 | loss  5.25 | ppl   189.74
# | epoch   6 |  1000/ 2981 batches | lr 5.00 | ms/batch 16.51 | loss  5.25 | ppl   189.68
# | epoch   6 |  1200/ 2981 batches | lr 5.00 | ms/batch 16.39 | loss  5.25 | ppl   191.10
# | epoch   6 |  1400/ 2981 batches | lr 5.00 | ms/batch 16.52 | loss  5.27 | ppl   193.46
# | epoch   6 |  1600/ 2981 batches | lr 5.00 | ms/batch 17.31 | loss  5.30 | ppl   201.07
# | epoch   6 |  1800/ 2981 batches | lr 5.00 | ms/batch 16.39 | loss  5.26 | ppl   192.47
# | epoch   6 |  2000/ 2981 batches | lr 5.00 | ms/batch 16.40 | loss  5.28 | ppl   195.40
# | epoch   6 |  2200/ 2981 batches | lr 5.00 | ms/batch 16.85 | loss  5.15 | ppl   173.09
# | epoch   6 |  2400/ 2981 batches | lr 5.00 | ms/batch 16.98 | loss  5.24 | ppl   187.90
# | epoch   6 |  2600/ 2981 batches | lr 5.00 | ms/batch 16.50 | loss  5.26 | ppl   191.74
# | epoch   6 |  2800/ 2981 batches | lr 5.00 | ms/batch 16.44 | loss  5.19 | ppl   178.86
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 52.75s | valid loss  5.40 | valid ppl   221.31
# -----------------------------------------------------------------------------------------
# =========================================================================================
# | End of training for 4 encoders | test loss  5.31 | test ppl   202.78
# =========================================================================================
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 19.68 | loss  8.42 | ppl  4554.54
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 20.43 | loss  7.49 | ppl  1798.93
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 19.43 | loss  7.20 | ppl  1339.77
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 19.42 | loss  7.08 | ppl  1182.94
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 20.29 | loss  7.03 | ppl  1125.94
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 19.32 | loss  7.02 | ppl  1117.75
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 19.53 | loss  6.97 | ppl  1058.93
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 20.43 | loss  6.96 | ppl  1058.22
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 19.36 | loss  6.94 | ppl  1035.19
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 19.39 | loss  6.96 | ppl  1054.20
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 20.19 | loss  6.93 | ppl  1025.14
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 19.40 | loss  6.93 | ppl  1018.82
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 19.34 | loss  6.92 | ppl  1016.07
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 19.94 | loss  6.90 | ppl   989.57
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 62.40s | valid loss  6.77 | valid ppl   867.04
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 5.00 | ms/batch 19.60 | loss  6.94 | ppl  1029.19
# | epoch   2 |   400/ 2981 batches | lr 5.00 | ms/batch 20.10 | loss  6.91 | ppl  1004.92
# | epoch   2 |   600/ 2981 batches | lr 5.00 | ms/batch 19.33 | loss  6.88 | ppl   977.32
# | epoch   2 |   800/ 2981 batches | lr 5.00 | ms/batch 19.40 | loss  6.91 | ppl  1002.43
# | epoch   2 |  1000/ 2981 batches | lr 5.00 | ms/batch 20.47 | loss  6.90 | ppl   992.84
# | epoch   2 |  1200/ 2981 batches | lr 5.00 | ms/batch 19.36 | loss  6.92 | ppl  1015.00
# | epoch   2 |  1400/ 2981 batches | lr 5.00 | ms/batch 19.51 | loss  6.90 | ppl   988.88
# | epoch   2 |  1600/ 2981 batches | lr 5.00 | ms/batch 20.44 | loss  6.92 | ppl  1012.35
# | epoch   2 |  1800/ 2981 batches | lr 5.00 | ms/batch 19.29 | loss  6.89 | ppl   986.59
# | epoch   2 |  2000/ 2981 batches | lr 5.00 | ms/batch 19.36 | loss  6.92 | ppl  1007.61
# | epoch   2 |  2200/ 2981 batches | lr 5.00 | ms/batch 20.29 | loss  6.89 | ppl   982.70
# | epoch   2 |  2400/ 2981 batches | lr 5.00 | ms/batch 19.33 | loss  6.89 | ppl   982.15
# | epoch   2 |  2600/ 2981 batches | lr 5.00 | ms/batch 19.34 | loss  6.89 | ppl   984.42
# | epoch   2 |  2800/ 2981 batches | lr 5.00 | ms/batch 20.66 | loss  6.87 | ppl   959.38
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 62.36s | valid loss  6.74 | valid ppl   849.27
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 5.00 | ms/batch 19.86 | loss  6.91 | ppl  1004.59
# | epoch   3 |   400/ 2981 batches | lr 5.00 | ms/batch 19.85 | loss  6.91 | ppl   997.28
# | epoch   3 |   600/ 2981 batches | lr 5.00 | ms/batch 19.36 | loss  6.87 | ppl   962.85
# | epoch   3 |   800/ 2981 batches | lr 5.00 | ms/batch 19.61 | loss  6.90 | ppl   988.79
# | epoch   3 |  1000/ 2981 batches | lr 5.00 | ms/batch 19.92 | loss  6.89 | ppl   978.31
# | epoch   3 |  1200/ 2981 batches | lr 5.00 | ms/batch 19.37 | loss  6.91 | ppl   997.69
# | epoch   3 |  1400/ 2981 batches | lr 5.00 | ms/batch 19.46 | loss  6.88 | ppl   972.22
# | epoch   3 |  1600/ 2981 batches | lr 5.00 | ms/batch 20.55 | loss  6.90 | ppl   991.01
# | epoch   3 |  1800/ 2981 batches | lr 5.00 | ms/batch 19.38 | loss  6.88 | ppl   974.22
# | epoch   3 |  2000/ 2981 batches | lr 5.00 | ms/batch 19.39 | loss  6.90 | ppl   989.20
# | epoch   3 |  2200/ 2981 batches | lr 5.00 | ms/batch 20.37 | loss  6.87 | ppl   964.35
# | epoch   3 |  2400/ 2981 batches | lr 5.00 | ms/batch 19.38 | loss  6.88 | ppl   969.22
# | epoch   3 |  2600/ 2981 batches | lr 5.00 | ms/batch 19.48 | loss  6.87 | ppl   960.77
# | epoch   3 |  2800/ 2981 batches | lr 5.00 | ms/batch 20.46 | loss  6.85 | ppl   940.25
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 62.27s | valid loss  6.79 | valid ppl   888.33
# -----------------------------------------------------------------------------------------
# | epoch   4 |   200/ 2981 batches | lr 5.00 | ms/batch 20.12 | loss  6.89 | ppl   981.19
# | epoch   4 |   400/ 2981 batches | lr 5.00 | ms/batch 19.67 | loss  6.88 | ppl   971.63
# | epoch   4 |   600/ 2981 batches | lr 5.00 | ms/batch 19.44 | loss  6.84 | ppl   938.88
# | epoch   4 |   800/ 2981 batches | lr 5.00 | ms/batch 19.89 | loss  6.88 | ppl   968.73
# | epoch   4 |  1000/ 2981 batches | lr 5.00 | ms/batch 19.78 | loss  6.87 | ppl   959.82
# | epoch   4 |  1200/ 2981 batches | lr 5.00 | ms/batch 19.39 | loss  6.88 | ppl   976.14
# | epoch   4 |  1400/ 2981 batches | lr 5.00 | ms/batch 19.72 | loss  6.86 | ppl   953.28
# | epoch   4 |  1600/ 2981 batches | lr 5.00 | ms/batch 20.17 | loss  6.86 | ppl   956.39
# | epoch   4 |  1800/ 2981 batches | lr 5.00 | ms/batch 19.17 | loss  6.86 | ppl   950.41
# | epoch   4 |  2000/ 2981 batches | lr 5.00 | ms/batch 19.40 | loss  6.88 | ppl   970.85
# | epoch   4 |  2200/ 2981 batches | lr 5.00 | ms/batch 20.17 | loss  6.87 | ppl   959.03
# | epoch   4 |  2400/ 2981 batches | lr 5.00 | ms/batch 19.29 | loss  6.85 | ppl   940.00
# | epoch   4 |  2600/ 2981 batches | lr 5.00 | ms/batch 19.42 | loss  6.84 | ppl   938.69
# | epoch   4 |  2800/ 2981 batches | lr 5.00 | ms/batch 20.51 | loss  6.82 | ppl   919.93
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 62.31s | valid loss  6.76 | valid ppl   866.42
# -----------------------------------------------------------------------------------------
# | epoch   5 |   200/ 2981 batches | lr 5.00 | ms/batch 20.45 | loss  6.87 | ppl   960.93
# | epoch   5 |   400/ 2981 batches | lr 5.00 | ms/batch 19.38 | loss  6.85 | ppl   945.72
# | epoch   5 |   600/ 2981 batches | lr 5.00 | ms/batch 19.37 | loss  6.82 | ppl   917.77
# | epoch   5 |   800/ 2981 batches | lr 5.00 | ms/batch 20.16 | loss  6.86 | ppl   951.14
# | epoch   5 |  1000/ 2981 batches | lr 5.00 | ms/batch 19.48 | loss  6.85 | ppl   940.28
# | epoch   5 |  1200/ 2981 batches | lr 5.00 | ms/batch 19.48 | loss  6.86 | ppl   957.77
# | epoch   5 |  1400/ 2981 batches | lr 5.00 | ms/batch 19.92 | loss  6.85 | ppl   941.07
# | epoch   5 |  1600/ 2981 batches | lr 5.00 | ms/batch 19.76 | loss  6.85 | ppl   943.85
# | epoch   5 |  1800/ 2981 batches | lr 5.00 | ms/batch 19.42 | loss  6.83 | ppl   928.57
# | epoch   5 |  2000/ 2981 batches | lr 5.00 | ms/batch 19.87 | loss  6.86 | ppl   950.88
# | epoch   5 |  2200/ 2981 batches | lr 5.00 | ms/batch 20.03 | loss  6.83 | ppl   923.45
# | epoch   5 |  2400/ 2981 batches | lr 5.00 | ms/batch 19.45 | loss  6.83 | ppl   924.98
# | epoch   5 |  2600/ 2981 batches | lr 5.00 | ms/batch 19.69 | loss  6.82 | ppl   918.34
# | epoch   5 |  2800/ 2981 batches | lr 5.00 | ms/batch 20.07 | loss  6.81 | ppl   905.89
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 62.27s | valid loss  6.85 | valid ppl   941.22
# -----------------------------------------------------------------------------------------
# | epoch   6 |   200/ 2981 batches | lr 5.00 | ms/batch 20.30 | loss  6.85 | ppl   944.11
# | epoch   6 |   400/ 2981 batches | lr 5.00 | ms/batch 19.40 | loss  6.84 | ppl   933.85
# | epoch   6 |   600/ 2981 batches | lr 5.00 | ms/batch 19.38 | loss  6.80 | ppl   894.88
# | epoch   6 |   800/ 2981 batches | lr 5.00 | ms/batch 20.40 | loss  6.83 | ppl   921.29
# | epoch   6 |  1000/ 2981 batches | lr 5.00 | ms/batch 19.51 | loss  6.83 | ppl   922.05
# | epoch   6 |  1200/ 2981 batches | lr 5.00 | ms/batch 19.26 | loss  6.85 | ppl   940.12
# | epoch   6 |  1400/ 2981 batches | lr 5.00 | ms/batch 20.32 | loss  6.82 | ppl   916.41
# | epoch   6 |  1600/ 2981 batches | lr 5.00 | ms/batch 19.43 | loss  6.83 | ppl   927.62
# | epoch   6 |  1800/ 2981 batches | lr 5.00 | ms/batch 19.44 | loss  6.82 | ppl   918.68
# | epoch   6 |  2000/ 2981 batches | lr 5.00 | ms/batch 20.14 | loss  6.84 | ppl   932.34
# | epoch   6 |  2200/ 2981 batches | lr 5.00 | ms/batch 19.43 | loss  6.81 | ppl   906.89
# | epoch   6 |  2400/ 2981 batches | lr 5.00 | ms/batch 19.49 | loss  6.82 | ppl   912.60
# | epoch   6 |  2600/ 2981 batches | lr 5.00 | ms/batch 20.17 | loss  6.81 | ppl   909.21
# | epoch   6 |  2800/ 2981 batches | lr 5.00 | ms/batch 19.89 | loss  6.79 | ppl   886.65
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 62.59s | valid loss  6.82 | valid ppl   916.68
# -----------------------------------------------------------------------------------------
# =========================================================================================
# | End of training for 6 encoders | test loss  6.76 | test ppl   862.60
# =========================================================================================
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 21.99 | loss  8.37 | ppl  4316.52
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 23.52 | loss  7.45 | ppl  1727.12
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 22.38 | loss  7.20 | ppl  1344.97
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 22.07 | loss  7.07 | ppl  1177.37
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 23.68 | loss  7.05 | ppl  1154.15
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 21.89 | loss  7.02 | ppl  1122.39
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 22.09 | loss  6.96 | ppl  1055.54
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 23.51 | loss  6.98 | ppl  1069.93
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 21.92 | loss  6.95 | ppl  1041.57
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 22.57 | loss  6.96 | ppl  1050.75
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 22.75 | loss  6.93 | ppl  1020.78
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 21.67 | loss  6.93 | ppl  1020.09
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 23.25 | loss  6.92 | ppl  1017.37
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 21.83 | loss  6.89 | ppl   987.09
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 71.78s | valid loss  6.79 | valid ppl   886.75
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 5.00 | ms/batch 21.95 | loss  6.94 | ppl  1031.21
# | epoch   2 |   400/ 2981 batches | lr 5.00 | ms/batch 22.00 | loss  6.92 | ppl  1008.66
# | epoch   2 |   600/ 2981 batches | lr 5.00 | ms/batch 23.94 | loss  6.89 | ppl   982.98
# | epoch   2 |   800/ 2981 batches | lr 5.00 | ms/batch 21.77 | loss  6.91 | ppl  1003.35
# | epoch   2 |  1000/ 2981 batches | lr 5.00 | ms/batch 22.29 | loss  6.90 | ppl   995.20
# | epoch   2 |  1200/ 2981 batches | lr 5.00 | ms/batch 23.00 | loss  6.91 | ppl  1006.45
# | epoch   2 |  1400/ 2981 batches | lr 5.00 | ms/batch 21.83 | loss  6.90 | ppl   989.24
# | epoch   2 |  1600/ 2981 batches | lr 5.00 | ms/batch 23.40 | loss  6.92 | ppl  1007.53
# | epoch   2 |  1800/ 2981 batches | lr 5.00 | ms/batch 22.07 | loss  6.89 | ppl   983.13
# | epoch   2 |  2000/ 2981 batches | lr 5.00 | ms/batch 21.72 | loss  6.92 | ppl  1009.17
# | epoch   2 |  2200/ 2981 batches | lr 5.00 | ms/batch 24.11 | loss  6.89 | ppl   981.95
# | epoch   2 |  2400/ 2981 batches | lr 5.00 | ms/batch 21.93 | loss  6.89 | ppl   985.14
# | epoch   2 |  2600/ 2981 batches | lr 5.00 | ms/batch 21.78 | loss  6.89 | ppl   986.46
# | epoch   2 |  2800/ 2981 batches | lr 5.00 | ms/batch 23.60 | loss  6.86 | ppl   956.40
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 71.45s | valid loss  6.74 | valid ppl   846.30
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 5.00 | ms/batch 23.25 | loss  6.92 | ppl  1007.90
# | epoch   3 |   400/ 2981 batches | lr 5.00 | ms/batch 21.81 | loss  6.90 | ppl   994.10
# | epoch   3 |   600/ 2981 batches | lr 5.00 | ms/batch 22.84 | loss  6.87 | ppl   959.06
# | epoch   3 |   800/ 2981 batches | lr 5.00 | ms/batch 22.48 | loss  6.90 | ppl   992.50
# | epoch   3 |  1000/ 2981 batches | lr 5.00 | ms/batch 21.90 | loss  6.88 | ppl   976.59
# | epoch   3 |  1200/ 2981 batches | lr 5.00 | ms/batch 23.43 | loss  6.90 | ppl   996.28
# | epoch   3 |  1400/ 2981 batches | lr 5.00 | ms/batch 21.69 | loss  6.88 | ppl   973.89
# | epoch   3 |  1600/ 2981 batches | lr 5.00 | ms/batch 21.61 | loss  6.90 | ppl   991.81
# | epoch   3 |  1800/ 2981 batches | lr 5.00 | ms/batch 23.72 | loss  6.89 | ppl   977.50
# | epoch   3 |  2000/ 2981 batches | lr 5.00 | ms/batch 21.77 | loss  6.90 | ppl   990.31
# | epoch   3 |  2200/ 2981 batches | lr 5.00 | ms/batch 22.11 | loss  6.88 | ppl   970.74
# | epoch   3 |  2400/ 2981 batches | lr 5.00 | ms/batch 23.22 | loss  6.87 | ppl   959.33
# | epoch   3 |  2600/ 2981 batches | lr 5.00 | ms/batch 21.63 | loss  6.88 | ppl   968.60
# | epoch   3 |  2800/ 2981 batches | lr 5.00 | ms/batch 22.93 | loss  6.84 | ppl   938.44
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 71.18s | valid loss  6.74 | valid ppl   846.51
# -----------------------------------------------------------------------------------------
# | epoch   4 |   200/ 2981 batches | lr 5.00 | ms/batch 23.73 | loss  6.90 | ppl   987.55
# | epoch   4 |   400/ 2981 batches | lr 5.00 | ms/batch 21.75 | loss  6.88 | ppl   973.34
# | epoch   4 |   600/ 2981 batches | lr 5.00 | ms/batch 21.76 | loss  6.85 | ppl   944.98
# | epoch   4 |   800/ 2981 batches | lr 5.00 | ms/batch 23.59 | loss  6.88 | ppl   970.35
# | epoch   4 |  1000/ 2981 batches | lr 5.00 | ms/batch 22.00 | loss  6.86 | ppl   955.86
# | epoch   4 |  1200/ 2981 batches | lr 5.00 | ms/batch 21.94 | loss  6.89 | ppl   977.55
# | epoch   4 |  1400/ 2981 batches | lr 5.00 | ms/batch 24.00 | loss  6.86 | ppl   951.34
# | epoch   4 |  1600/ 2981 batches | lr 5.00 | ms/batch 22.07 | loss  6.87 | ppl   967.23
# | epoch   4 |  1800/ 2981 batches | lr 5.00 | ms/batch 22.93 | loss  6.86 | ppl   950.89
# | epoch   4 |  2000/ 2981 batches | lr 5.00 | ms/batch 22.81 | loss  6.87 | ppl   966.87
# | epoch   4 |  2200/ 2981 batches | lr 5.00 | ms/batch 21.81 | loss  6.85 | ppl   946.86
# | epoch   4 |  2400/ 2981 batches | lr 5.00 | ms/batch 23.77 | loss  6.84 | ppl   938.97
# | epoch   4 |  2600/ 2981 batches | lr 5.00 | ms/batch 21.85 | loss  6.84 | ppl   938.97
# | epoch   4 |  2800/ 2981 batches | lr 5.00 | ms/batch 22.04 | loss  6.83 | ppl   921.80
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 71.87s | valid loss  6.81 | valid ppl   909.04
# -----------------------------------------------------------------------------------------
# | epoch   5 |   200/ 2981 batches | lr 5.00 | ms/batch 22.03 | loss  6.86 | ppl   957.55
# | epoch   5 |   400/ 2981 batches | lr 5.00 | ms/batch 23.66 | loss  6.85 | ppl   946.04
# | epoch   5 |   600/ 2981 batches | lr 5.00 | ms/batch 21.87 | loss  6.82 | ppl   914.08
# | epoch   5 |   800/ 2981 batches | lr 5.00 | ms/batch 22.76 | loss  6.85 | ppl   941.41
# | epoch   5 |  1000/ 2981 batches | lr 5.00 | ms/batch 22.61 | loss  6.84 | ppl   938.73
# | epoch   5 |  1200/ 2981 batches | lr 5.00 | ms/batch 21.60 | loss  6.86 | ppl   954.67
# | epoch   5 |  1400/ 2981 batches | lr 5.00 | ms/batch 23.63 | loss  6.84 | ppl   937.69
# | epoch   5 |  1600/ 2981 batches | lr 5.00 | ms/batch 22.16 | loss  6.85 | ppl   939.56
# | epoch   5 |  1800/ 2981 batches | lr 5.00 | ms/batch 21.83 | loss  6.84 | ppl   931.37
# | epoch   5 |  2000/ 2981 batches | lr 5.00 | ms/batch 23.51 | loss  6.86 | ppl   949.15
# | epoch   5 |  2200/ 2981 batches | lr 5.00 | ms/batch 22.11 | loss  6.83 | ppl   921.25
# | epoch   5 |  2400/ 2981 batches | lr 5.00 | ms/batch 22.22 | loss  6.81 | ppl   910.83
# | epoch   5 |  2600/ 2981 batches | lr 5.00 | ms/batch 23.10 | loss  6.82 | ppl   918.27
# | epoch   5 |  2800/ 2981 batches | lr 5.00 | ms/batch 21.71 | loss  6.80 | ppl   895.50
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 71.65s | valid loss  6.79 | valid ppl   889.83
# -----------------------------------------------------------------------------------------
# | epoch   6 |   200/ 2981 batches | lr 5.00 | ms/batch 21.88 | loss  6.84 | ppl   935.96
# | epoch   6 |   400/ 2981 batches | lr 5.00 | ms/batch 23.28 | loss  6.83 | ppl   928.77
# | epoch   6 |   600/ 2981 batches | lr 5.00 | ms/batch 21.81 | loss  6.79 | ppl   891.45
# | epoch   6 |   800/ 2981 batches | lr 5.00 | ms/batch 21.88 | loss  6.82 | ppl   917.07
# | epoch   6 |  1000/ 2981 batches | lr 5.00 | ms/batch 23.47 | loss  6.81 | ppl   909.68
# | epoch   6 |  1200/ 2981 batches | lr 5.00 | ms/batch 21.77 | loss  6.83 | ppl   926.94
# | epoch   6 |  1400/ 2981 batches | lr 5.00 | ms/batch 21.96 | loss  6.81 | ppl   910.61
# | epoch   6 |  1600/ 2981 batches | lr 5.00 | ms/batch 23.50 | loss  6.83 | ppl   921.10
# | epoch   6 |  1800/ 2981 batches | lr 5.00 | ms/batch 21.70 | loss  6.81 | ppl   907.65
# | epoch   6 |  2000/ 2981 batches | lr 5.00 | ms/batch 22.80 | loss  6.83 | ppl   925.93
# | epoch   6 |  2200/ 2981 batches | lr 5.00 | ms/batch 22.58 | loss  6.80 | ppl   901.37
# | epoch   6 |  2400/ 2981 batches | lr 5.00 | ms/batch 21.83 | loss  6.79 | ppl   889.54
# | epoch   6 |  2600/ 2981 batches | lr 5.00 | ms/batch 23.45 | loss  6.80 | ppl   894.90
# | epoch   6 |  2800/ 2981 batches | lr 5.00 | ms/batch 21.81 | loss  6.78 | ppl   877.13
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 71.53s | valid loss  6.84 | valid ppl   932.80
# -----------------------------------------------------------------------------------------
# =========================================================================================
# | End of training for 8 encoders | test loss  6.78 | test ppl   877.75
# =========================================================================================

# %%
import matplotlib.pyplot as plt

plt.title("Test performance - Number of encoders") # Set graph/figure title
plt.ylabel("Test ppl") # Set y-axis title
plt.xlabel("Number of encoders") # Set x-axis title

encoders = n_encoders_list # assume we try head number of 1, 2, 4, and 8 (i.e., 4 variants)
ppls = [math.exp(test_loss[-1]) for test_loss in epoch_test_losses] # assume we get the corresponding test ppl using each variant head number - you need to get them from your own experiments
plt.bar(encoders, ppls) # plot the bar chart

plt.show() # show the bar chart

# %%
from tabulate import tabulate
encoders = n_encoders_list # assume we try head number of 1, 2, 4, and 8 (i.e., 4 variants)
ppls = [math.exp(test_loss[-1]) for test_loss in epoch_test_losses]  # assume we get the corresponding test ppl using each variant head number - you need to get them from your own experiments
table = [['']+['encoders '+str(encoders) for encoders in n_encoders_list], ['Test ppl']+ppls]
print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒══════════╤══════════════╤══════════════╤══════════════╕
# │          │   encoders 4 │   encoders 6 │   encoders 8 │
# ╞══════════╪══════════════╪══════════════╪══════════════╡
# │ Test ppl │      221.315 │      916.683 │      932.801 │
# ╘══════════╧══════════════╧══════════════╧══════════════╛

# %%
import matplotlib.pyplot as plt
import random

plt.title("Validation performance - Number of encoders") # Set graph/figure title
plt.ylabel("Validation performance") # Set y-axis title
plt.xlabel("Number of epochs") # Set x-axis title

# encoders = n_encoders_list # assume we tried 4 variants of encoder layers

for i, encoders in enumerate(n_encoders_list): # for each encoder variant, we will draw one line graph, showing the validation loss of each epoch
  epochs = [1,2,3,4,5,6] # for each variant, we apply 3 epochs. Thus, we will have epoch 1, 2, 3 (or 0, 1, 2 if you starts with 0)
  val_losses = epoch_test_losses[i] # for each epoch, we recorded the validation loss. Note that here we apply random numbers only for demonstration. However, you need to record your real validation loss if needed.
  plt.plot(epochs,val_losses, label="{0} encoders".format(encoders)) # label each line graph with the encoder number (see the actual plotting in the graph below)

plt.legend(); # this turns on the legends, which shows the label for each line graph. You can comment it out and rerun the code to see the difference
plt.show() # show the final figure

# %%
from tabulate import tabulate

table=[]
epochs = [1,2,3,4,5,6] # for each variant, we apply 3 epochs. Thus, we will have epoch 1, 2, 3 (or 0, 1, 2 if you starts with 0)

table.append(['']+['epoch '+str(epoch) for epoch in epochs]) # append encoder numbers as header

for i, encoders in enumerate(n_encoders_list): # for each encoder variant, we will have validation loss for each epoch
  
  val_losses = epoch_test_losses[i] # for each epoch, we recorded the validation loss. Note that here we apply random numbers only for demonstration. However, you need to record your real validation loss if needed.
  table.append(['encoder '+str(encoders)]+val_losses) # append each row data to the table

print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒═══════════╤═══════════╤═══════════╤═══════════╤═══════════╤═══════════╤═══════════╕
# │           │   epoch 1 │   epoch 2 │   epoch 3 │   epoch 4 │   epoch 5 │   epoch 6 │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ encoder 4 │   5.77317 │   5.62053 │   5.51904 │   5.46642 │   5.42637 │   5.39959 │
# ├───────────┼───────────┼───────────┼───────────┼───────────┼───────────┼───────────┤
# │ encoder 6 │   6.76509 │   6.74438 │   6.78934 │   6.76437 │   6.84718 │   6.82076 │
# ├───────────┼───────────┼───────────┼───────────┼───────────┼───────────┼───────────┤
# │ encoder 8 │   6.78756 │   6.74087 │   6.74113 │   6.81239 │   6.79103 │   6.83819 │
# ╘═══════════╧═══════════╧═══════════╧═══════════╧═══════════╧═══════════╧═══════════╛

# %% [markdown]
# ## Sample outputs

# %% [markdown]
# Below are several sample outputs for your reference. The code for deriving the corresponding results will be released in the sample solution later. Your visualization can be different based on your own experiments setups and your intention of visualization.

# %% [markdown]
# ![Image1.png](data:image/png;base64,...)

# %% [markdown]
# ![Image2.png](data:image/png;base64,...)

# %% [markdown]
# ![Image3.png](data:image/png;base64,...)

# %% [markdown]
# ![Image4.png](data:image/png;base64,...)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

def scaled_dot_product_attention(query, key, value, mask=None):
    """
    Calculate the attention weights.
    query shape: (batch_size, num_heads, seq_len_q, depth)
    key shape: (batch_size, num_heads, seq_len_k, depth)
    value shape: (batch_size, num_heads, seq_len_v, depth_v)
    mask shape: (batch_size, 1, 1, seq_len_k)
    """
    # Calculate the dot product between the query and key
    matmul_qk = torch.matmul(query, key.transpose(-1,-2))
    
    # Scale the dot product
    dk = key.shape[-1]
    scaled_attention_logits = matmul_qk / torch.sqrt(torch.tensor(dk,dtype=torch.float32))
    
    # Apply the mask if provided
    if mask is not None:
        scaled_attention_logits += (mask * -1e9)
    
    # Calculate the attention weights
    attention_weights = F.softmax(scaled_attention_logits, dim=-1)
    
    # Calculate the weighted average of the values
    output = torch.matmul(attention_weights, value)
    
    return output, attention_weights
